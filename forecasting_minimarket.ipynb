# %% [markdown]
# <a href="https://colab.research.google.com/github/zhulkhoirrifat/Air-Quality-Analysis/blob/main/forecasting_minimarket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Library
#
# Langkah pertama adalah mengimpor library yang dibutuhkan untuk proses data dan machine learning.
#
# - `pandas` dan `numpy` untuk manipulasi data
# - `matplotlib` dan `seaborn` untuk visualisasi
# - `sklearn` untuk preprocessing dan model ML

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ## Load dan Persiapan Data
#
# Dataset diambil dari file CSV. Setelah itu, dilakukan pengecekan awal seperti:
# - Menampilkan 5 data teratas
# - Melihat tipe data dan jumlah missing values
# - Menampilkan statistik deskriptif
# - Menghapus kolom yang tidak relevan
# - Mengubah tipe data jika diperlukan

# %%
products_df = pd.read_csv('products.csv')
transactions_df = pd.read_csv('transactions.csv')
transaction_details_df = pd.read_csv('transaction_details.csv')
stores_df = pd.read_csv('stores.csv')

# %%
transactions_df.columns
# Out:
# Index(['transactionId', 'invoiceId', 'customerId', 'userId', 'storeId',
#        'paymentMethodId', 'totalAmount', 'cash', 'change', 'discount',
#        'transactionDate', 'status'],
#       dtype='object')

# %%
transactions_df = transactions_df.rename(columns={'discount': 'discountPerson', 'status': 'statusTransaction' })

# %%
transactions_df
# Out:
#        transactionId         invoiceId  customerId  userId  storeId  \
# 0                  1  INV-254458877494         NaN      72        1
# 1                  2  INV-470601977760      3786.0      96        1
# 2                  3  INV-993764067901      4174.0      72        1
# 3                  4  INV-639098207995      3826.0     146        1
# 4                  5  INV-836595708581      4733.0     146        1
# ...              ...               ...         ...     ...      ...
# 89309          89310  INV-630086877748         NaN      70       30
# 89310          89311  INV-239106088596         NaN     160       30
# 89311          89312  INV-746790987436         NaN      70       30
# 89312          89313  INV-628220039782      1587.0      70       30
# 89313          89314  INV-586130080270         NaN      70       30
#
#        paymentMethodId  totalAmount        cash  change  discountPerson  \
# 0                    3    560558.88   565214.88  4656.0               0
# 1                    3   2186634.24  2187163.24   529.0               0
# 2                    2   3280314.24  3280314.24     0.0               0
# 3                    7   3684522.24  3685947.24  1425.0               0
# 4                    2   1149110.28  1149110.28     0.0               3
# ...                ...          ...         ...     ...             ...
# 89309                1   6099027.28  6101775.28  2748.0              10
# 89310                2    137121.60   137121.60     0.0               0
# 89311                4   2510026.40  2510085.40    59.0               0
# 89312                4    878111.36   882316.36  4205.0               0
# 89313                6   2287082.56  2290423.56  3341.0               0
#
#            transactionDate statusTransaction
# 0      2024-01-02 11:25:07         COMPLETED
# 1      2024-01-07 10:30:14         COMPLETED
# 2      2024-01-01 21:29:06         COMPLETED
# 3      2024-01-06 21:21:34         COMPLETED
# 4      2024-01-01 10:19:03         COMPLETED
# ...                    ...               ...
# 89309  2025-03-10 09:46:00         COMPLETED
# 89310  2025-03-10 09:27:13         COMPLETED
# 89311  2025-03-11 08:18:52         COMPLETED
# 89312  2025-03-12 15:40:17         COMPLETED
# 89313  2025-03-03 17:04:07         COMPLETED
#
# [89314 rows x 12 columns]

# %%
transaction_details_df.columns
# Out:
# Index(['transactionDetailId', 'transactionId', 'productId', 'variantId',
#        'quantity', 'subtotal'],
#       dtype='object')

# %%
transaction_details_df
# Out:
#         transactionDetailId  transactionId  productId  variantId  quantity  \
# 0                         1              1          1          1         3
# 1                         2              2          2          2         2
# 2                         3              2          5          5         1
# 3                         4              2          6          6         1
# 4                         5              2          3          3         2
# ...                     ...            ...        ...        ...       ...
# 267625               267626          89313        311        311         4
# 267626               267627          89314        315        315         1
# 267627               267628          89314        305        305         3
# 267628               267629          89314        313        313         5
# 267629               267630          89314        311        311         3
#
#         subtotal
# 0         500499
# 1        1190478
# 2         235408
# 3          75242
# 4         451224
# ...          ...
# 267625    784028
# 267626     28432
# 267627    470550
# 267628    955035
# 267629    588021
#
# [267630 rows x 6 columns]

# %%
products_df.columns
# Out:
# Index(['productId', 'productCode', 'serialNumber', 'categoryId', 'name',
#        'description', 'discount', 'basePrice', 'imageUrl', 'isActive',
#        'createdAt', 'updatedAt'],
#       dtype='object')

# %%
products_df = products_df.rename(columns={
    'name': 'productName',
    'description': 'descriptionProduct',
    'discount': 'productDiscount'
})

# %%
products_df
# Out:
#      productId productCode  serialNumber  categoryId  \
# 0            1  PRD-730565      858853.0          27
# 1            2  PRD-443514      133692.0          40
# 2            3  PRD-126772           NaN          40
# 3            4  PRD-897193      280004.0          28
# 4            5  PRD-269296      955177.0          36
# ..         ...         ...           ...         ...
# 311        312  PRD-583648      351536.0         103
# 312        313  PRD-808382      132302.0         103
# 313        314  PRD-412585      451269.0         102
# 314        315  PRD-476592      308845.0         101
# 315        316  PRD-554250      828280.0         103
#
#                              productName  \
# 0                Moistruizer Consectetur
# 1                        Catokan Nostrum
# 2                         Catokan Facere
# 3             Sunscreen Wajah Reiciendis
# 4                             Parfum Non
# ..                                   ...
# 311         Makanan Hewan Peliharaan Nam
# 312  Makanan Hewan Peliharaan Recusandae
# 313      Kandang dan Aksesoris Hewan Qui
# 314                      Pakan Ternak At
# 315       Makanan Hewan Peliharaan Autem
#
#                                     descriptionProduct  productDiscount  \
# 0    Labore nulla tempore saepe aut quia nesciunt q...               18
# 1    Saepe maxime est assumenda exercitationem sint...                1
# 2    In perspiciatis ratione sint itaque soluta cup...                0
# 3    Nam placeat cum accusamus nesciunt praesentium...                0
# 4    Earum inventore dignissimos vel molestiae vita...                0
# ..                                                 ...              ...
# 311  Voluptas quis aspernatur fugit ducimus iste an...                0
# 312  Nobis fugiat repudiandae placeat quod officia ...                0
# 313  Quidem ut aspernatur quisquam necessitatibus n...               19
# 314  Deserunt suscipit quod enim tempora architecto...                5
# 315  Dolorem nihil neque saepe itaque beatae conseq...                0
#
#      basePrice                          imageUrl  isActive  \
# 0       133000    https://placekitten.com/21/644      True
# 1       563000   https://placekitten.com/656/993      True
# 2       187000     https://picsum.photos/585/553      True
# 3       104000  https://placekitten.com/942/1012      True
# 4       204000    https://placekitten.com/463/11      True
# ..         ...                               ...       ...
# 311     166000    https://dummyimage.com/115x893      True
# 312     181000    https://placekitten.com/873/38      True
# 313     900000     https://picsum.photos/343/889      True
# 314      12000     https://picsum.photos/102/697      True
# 315      60000   https://placekitten.com/157/414      True
#
#                       createdAt                   updatedAt
# 0    2025-03-06T23:04:21.869675  2025-01-17T19:02:58.287229
# 1    2025-03-19T21:36:46.214944  2025-01-21T18:43:23.091461
# 2    2025-02-09T14:05:00.296969  2025-03-14T21:51:10.920836
# 3    2025-03-28T21:21:02.654258  2025-01-14T03:20:10.318053
# 4    2025-04-03T01:53:26.003530  2025-04-10T00:55:12.170151
# ..                          ...                         ...
# 311  2025-04-06T00:11:48.351492  2025-01-12T13:32:47.589411
# 312  2025-04-07T02:26:17.874365  2025-01-02T06:56:07.291189
# 313  2025-04-05T21:30:28.402859  2025-02-18T06:53:10.926951
# 314  2025-02-19T05:38:08.506213  2025-03-28T05:14:23.561069
# 315  2025-02-24T01:19:59.222243  2025-02-19T14:50:32.949203
#
# [316 rows x 12 columns]

# %%
stores_df.columns
# Out:
# Index(['storeId', 'StoreCode', 'tenantId', 'name', 'image', 'address',
#        'provinceId', 'cityId', 'districtId', 'villageId', 'storeTypeId',
#        'postalCode', 'description', 'phoneNumber', 'logo', 'npwpCompany',
#        'permitCertificate', 'status'],
#       dtype='object')

# %%
stores_df = stores_df.rename(columns={
    'name': 'storeName',
    'description': 'storeDescription',
    'status': 'storeStatus'
})

# %%
stores_df
# Out:
#     storeId         StoreCode  tenantId  \
# 0         1  STR-274408152573         1
# 1         2  STR-864455930633         1
# 2         3  STR-981272582949         1
# 3         4  STR-669558699359         1
# 4         5  STR-762407648691         2
# 5         6  STR-314119394226         2
# 6         7  STR-750382527548         3
# 7         8  STR-104061397935         3
# 8         9  STR-480258745722         3
# 9        10  STR-963207851371         3
# 10       11  STR-648418917314         4
# 11       12  STR-228407136301         4
# 12       13  STR-159937056815         4
# 13       14  STR-151903670237         4
# 14       15  STR-612645875701         4
# 15       16  STR-149548347757         5
# 16       17  STR-257823245067         5
# 17       18  STR-473953025572         5
# 18       19  STR-668374382906         6
# 19       20  STR-709842743411         6
# 20       21  STR-254383735332         6
# 21       22  STR-842949079668         6
# 22       23  STR-568497891076         7
# 23       24  STR-626679597272         8
# 24       25  STR-129653782125         8
# 25       26  STR-489600497195         8
# 26       27  STR-607881918314         9
# 27       28  STR-550090318488         9
# 28       29  STR-970351536952        10
# 29       30  STR-889468304884        10
#
#                                             storeName  \
# 0               Perawatan Diri & Kecantikan Tarihoran
# 1                         Makanan & Minuman Tarihoran
# 2      Perawatan Diri & Kecantikan Tarihoran Cabang 2
# 3      Perlengkapan Rumah Tangga & Dekorasi Tarihoran
# 4                   Peralatan Bayi & Anak Nashiruddin
# 5                       Makanan & Minuman Nashiruddin
# 6                    Peralatan Bayi & Anak Nainggolan
# 7         Mainan, Hobi & Peralatan Outdoor Nainggolan
# 8          Elektronik, Gadget & Alat Musik Nainggolan
# 9   Mainan, Hobi & Peralatan Outdoor Nainggolan Ca...
# 10                          Makanan & Minuman Hidayat
# 11                           Produk Kesehatan Hidayat
# 12                     Otomotif & Suku Cadang Hidayat
# 3    https://placekitten.com/965/442      ACTIVE
# 4       https://picsum.photos/79/687      ACTIVE
# 5    https://placekitten.com/802/981      ACTIVE
# 6      https://picsum.photos/858/571      ACTIVE
# 7      https://dummyimage.com/16x575      ACTIVE
# 8    https://placekitten.com/285/821      ACTIVE
# 9    https://placekitten.com/197/180      ACTIVE
# 10   https://placekitten.com/273/795      ACTIVE
# 11      https://picsum.photos/513/30      ACTIVE
# 12    https://dummyimage.com/313x530      ACTIVE
# 13    https://dummyimage.com/907x810      ACTIVE
# 14    https://placekitten.com/21/893      ACTIVE
# 15   https://placekitten.com/750/385      ACTIVE
# 16      https://dummyimage.com/76x49      ACTIVE
# 17     https://placekitten.com/764/4      ACTIVE
# 18   https://placekitten.com/497/855      ACTIVE
# 19     https://picsum.photos/646/954      ACTIVE
# 20    https://dummyimage.com/800x649      ACTIVE
# 21     https://picsum.photos/448/634      ACTIVE
# 22   https://placekitten.com/994/518      ACTIVE
# 23     https://picsum.photos/100/308      ACTIVE
# 24  https://placekitten.com/589/1018      ACTIVE
# 25     https://dummyimage.com/67x401      ACTIVE
# 26    https://dummyimage.com/590x738      ACTIVE
# 27   https://placekitten.com/851/695      ACTIVE
# 28   https://placekitten.com/429/434      ACTIVE
# 29    https://dummyimage.com/641x790      ACTIVE

# %%
# menggabungkan dataframe product dan store_fnb
merge_step1 = pd.merge(transactions_df, transaction_details_df, on='transactionId', how='left')
merge_step1
# Out:
#         transactionId         invoiceId  customerId  userId  storeId  \
# 0                   1  INV-254458877494         NaN      72        1
# 1                   2  INV-470601977760      3786.0      96        1
# 2                   2  INV-470601977760      3786.0      96        1
# 3                   2  INV-470601977760      3786.0      96        1
# 4                   2  INV-470601977760      3786.0      96        1
# ...               ...               ...         ...     ...      ...
# 267625          89313  INV-628220039782      1587.0      70       30
# 267626          89314  INV-586130080270         NaN      70       30
# 267627          89314  INV-586130080270         NaN      70       30
# 267628          89314  INV-586130080270         NaN      70       30
# 267629          89314  INV-586130080270         NaN      70       30
#
#         paymentMethodId  totalAmount        cash  change  discountPerson  \
# 0                     3    560558.88   565214.88  4656.0               0
# 1                     3   2186634.24  2187163.24   529.0               0
# 2                     3   2186634.24  2187163.24   529.0               0
# 3                     3   2186634.24  2187163.24   529.0               0
# 4                     3   2186634.24  2187163.24   529.0               0
# ...                 ...          ...         ...     ...             ...
# 267625                4    878111.36   882316.36  4205.0               0
# 267626                6   2287082.56  2290423.56  3341.0               0
# 267627                6   2287082.56  2290423.56  3341.0               0
# 267628                6   2287082.56  2290423.56  3341.0               0
# 267629                6   2287082.56  2290423.56  3341.0               0
#
#             transactionDate statusTransaction  transactionDetailId  productId  \
# 0       2024-01-02 11:25:07         COMPLETED                    1          1
# 1       2024-01-07 10:30:14         COMPLETED                    2          2
# 2       2024-01-07 10:30:14         COMPLETED                    3          5
# 3       2024-01-07 10:30:14         COMPLETED                    4          6
# 4       2024-01-07 10:30:14         COMPLETED                    5          3
# ...                     ...               ...                  ...        ...
# 267625  2025-03-12 15:40:17         COMPLETED               267626        311
# 267626  2025-03-03 17:04:07         COMPLETED               267627        315
# 267627  2025-03-03 17:04:07         COMPLETED               267628        305
# 267628  2025-03-03 17:04:07         COMPLETED               267629        313
# 267629  2025-03-03 17:04:07         COMPLETED               267630        311
#
#         variantId  quantity  subtotal
# 0               1         3    500499
# 1               2         2   1190478
# 2               5         1    235408
# 3               6         1     75242
# 4               3         2    451224
# ...           ...       ...       ...
# 267625        311         4    784028
# 267626        315         1     28432
# 267627        305         3    470550
# 267628        313         5    955035
# 267629        311         3    588021
#
# [267630 rows x 17 columns]

# %%
# menggabungkan dataframe transaction dan products_stores_fnb
merge_step2 = pd.merge(merge_step1, products_df, on='productId', how='left')
merge_step2
# Out:
#         transactionId         invoiceId  customerId  userId  storeId  \
# 0                   1  INV-254458877494         NaN      72        1
# 1                   2  INV-470601977760      3786.0      96        1
# 2                   2  INV-470601977760      3786.0      96        1
# 3                   2  INV-470601977760      3786.0      96        1
# 4                   2  INV-470601977760      3786.0      96        1
# ...               ...               ...         ...     ...      ...
# 267625          89313  INV-628220039782      1587.0      70       30
# 267626          89314  INV-586130080270         NaN      70       30
# 267627          89314  INV-586130080270         NaN      70       30
# 267628          89314  INV-586130080270         NaN      70       30
# 267629          89314  INV-586130080270         NaN      70       30
#
#         paymentMethodId  totalAmount        cash  change  discountPerson  ...  \
# 0                     3    560558.88   565214.88  4656.0               0  ...
# 1                     3   2186634.24  2187163.24   529.0               0  ...
# 2                     3   2186634.24  2187163.24   529.0               0  ...
# 3                     3   2186634.24  2187163.24   529.0               0  ...
# 4                     3   2186634.24  2187163.24   529.0               0  ...
# ...                 ...          ...         ...     ...             ...  ...
# 267625                4    878111.36   882316.36  4205.0               0  ...
# 267626                6   2287082.56  2290423.56  3341.0               0  ...
# 267627                6   2287082.56  2290423.56  3341.0               0  ...
# 267628                6   2287082.56  2290423.56  3341.0               0  ...
# 267629                6   2287082.56  2290423.56  3341.0               0  ...
#
#        serialNumber categoryId                          productName  \
# 0          858853.0         27              Moistruizer Consectetur
# 1          133692.0         40                      Catokan Nostrum
# 2          955177.0         36                           Parfum Non
# 3               NaN         35                         Pomade Ullam
# 4               NaN         40                       Catokan Facere
# ...             ...        ...                                  ...
# 267625          NaN        103   Makanan Hewan Peliharaan Occaecati
# 267626     308845.0        101                      Pakan Ternak At
# 267627     871686.0        103       Makanan Hewan Peliharaan Atque
# 267628     132302.0        103  Makanan Hewan Peliharaan Recusandae
# 267629          NaN        103   Makanan Hewan Peliharaan Occaecati
#
#                                        descriptionProduct  productDiscount  \
# 0       Labore nulla tempore saepe aut quia nesciunt q...               18
# 1       Saepe maxime est assumenda exercitationem sint...                1
# 2       Earum inventore dignissimos vel molestiae vita...                0
# 3       Accusamus quod quia nesciunt fuga itaque moles...                0
# 4       In perspiciatis ratione sint itaque soluta cup...                0
# ...                                                   ...              ...
# 267625           Delectus aut nulla deserunt ut corporis.                0
# 267626  Deserunt suscipit quod enim tempora architecto...                5
# 267627  Incidunt occaecati eos voluptatibus eaque culp...                0
# 267628  Nobis fugiat repudiandae placeat quod officia ...                0
# 267629           Delectus aut nulla deserunt ut corporis.                0
#
#         basePrice                         imageUrl isActive  \
# 0          133000   https://placekitten.com/21/644     True
# 1          563000  https://placekitten.com/656/993     True
# 2          204000   https://placekitten.com/463/11     True
# 3           49000    https://picsum.photos/432/124     True
# 4          187000    https://picsum.photos/585/553     True
# ...           ...                              ...      ...
# 267625     186000   https://dummyimage.com/555x470     True
# 267626      12000    https://picsum.photos/102/697     True
# 267627     110000    https://picsum.photos/926/840     True
# 267628     181000   https://placekitten.com/873/38     True
# 267629     186000   https://dummyimage.com/555x470     True
#
#                          createdAt                   updatedAt
# 0       2025-03-06T23:04:21.869675  2025-01-17T19:02:58.287229
# 1       2025-03-19T21:36:46.214944  2025-01-21T18:43:23.091461
# 2       2025-04-03T01:53:26.003530  2025-04-10T00:55:12.170151
# 3       2025-02-05T20:06:04.546859  2025-03-11T13:36:02.597779
# 4       2025-02-09T14:05:00.296969  2025-03-14T21:51:10.920836
# ...                            ...                         ...
# 267625  2025-01-01T12:48:45.446591  2025-01-03T20:45:25.231429
# 267626  2025-02-19T05:38:08.506213  2025-03-28T05:14:23.561069
# 267627  2025-04-05T06:17:58.179626  2025-01-03T18:14:48.020152
# 267628  2025-04-07T02:26:17.874365  2025-01-02T06:56:07.291189
# 267629  2025-01-01T12:48:45.446591  2025-01-03T20:45:25.231429
#
# [267630 rows x 28 columns]

# %%
final_df = pd.merge(merge_step2, stores_df, on='storeId', how='left')
final_df
# Out:
#         transactionId         invoiceId  customerId  userId  storeId  \
# 0                   1  INV-254458877494         NaN      72        1
# 1                   2  INV-470601977760      3786.0      96        1
# 2                   2  INV-470601977760      3786.0      96        1
# 3                   2  INV-470601977760      3786.0      96        1
# 4                   2  INV-470601977760      3786.0      96        1
# ...               ...               ...         ...     ...      ...
# 267625          89313  INV-628220039782      1587.0      70       30
# 267626          89314  INV-586130080270         NaN      70       30
# 267627          89314  INV-586130080270         NaN      70       30
# 267628          89314  INV-586130080270         NaN      70       30
# 267629          89314  INV-586130080270         NaN      70       30
#
#         paymentMethodId  totalAmount        cash  change  discountPerson  ...  \
# 0                     3    560558.88   565214.88  4656.0               0  ...
# 1                     3   2186634.24  2187163.24   529.0               0  ...
# 2                     3   2186634.24  2187163.24   529.0               0  ...
# 3                     3   2186634.24  2187163.24   529.0               0  ...
# 4                     3   2186634.24  2187163.24   529.0               0  ...
# ...                 ...          ...         ...     ...             ...  ...
# 267625                4    878111.36   882316.36  4205.0               0  ...
# 267626                6   2287082.56  2290423.56  3341.0               0  ...
# 267627                6   2287082.56  2290423.56  3341.0               0  ...
# 267628                6   2287082.56  2290423.56  3341.0               0  ...
# 267629                6   2287082.56  2290423.56  3341.0               0  ...
#
#        districtId villageId  storeTypeId  postalCode  \
# 0            5579     62967            3       37086
# 1            5579     62967            3       37086
# 2            5579     62967            3       37086
# 3            5579     62967            3       37086
# 4            5579     62967            3       37086
# ...           ...       ...          ...         ...
# 267625       5693     60379            7       76498
# 267626       5693     60379            7       76498
# 267627       5693     60379            7       76498
# 267628       5693     60379            7       76498
# 267629       5693     60379            7       76498
#
#                                          storeDescription   phoneNumber  \
# 0       Ea cum culpa dolor debitis. Animi porro in ita...  628189008565
# 1       Ea cum culpa dolor debitis. Animi porro in ita...  628189008565
# 2       Ea cum culpa dolor debitis. Animi porro in ita...  628189008565
# 3       Ea cum culpa dolor debitis. Animi porro in ita...  628189008565
# 4       Ea cum culpa dolor debitis. Animi porro in ita...  628189008565
# ...                                                   ...           ...
# 267625  Consequatur eum repellendus quaerat quisquam. ...  628180869741
# 267626  Consequatur eum repellendus quaerat quisquam. ...  628180869741
# 267627  Consequatur eum repellendus quaerat quisquam. ...  628180869741
# 267628  Consequatur eum repellendus quaerat quisquam. ...  628180869741
# 267629  Consequatur eum repellendus quaerat quisquam. ...  628180869741
#
#                                   logo                      npwpCompany  \
# 0       https://dummyimage.com/308x883  https://placekitten.com/416/679
# 1       https://dummyimage.com/308x883  https://placekitten.com/416/679
# 2       https://dummyimage.com/308x883  https://placekitten.com/416/679
# 3       https://dummyimage.com/308x883  https://placekitten.com/416/679
# 4       https://dummyimage.com/308x883  https://placekitten.com/416/679
# ...                                ...                              ...
# 267625  https://dummyimage.com/680x153    https://picsum.photos/337/248
# 267626  https://dummyimage.com/680x153    https://picsum.photos/337/248
# 267627  https://dummyimage.com/680x153    https://picsum.photos/337/248
# 267628  https://dummyimage.com/680x153    https://picsum.photos/337/248
# 267629  https://dummyimage.com/680x153    https://picsum.photos/337/248
#
#                      permitCertificate  storeStatus
# 0       https://placekitten.com/622/73       ACTIVE
# 1       https://placekitten.com/622/73       ACTIVE
# 2       https://placekitten.com/622/73       ACTIVE
# 3       https://placekitten.com/622/73       ACTIVE
# 4       https://placekitten.com/622/73       ACTIVE
# ...                                ...          ...
# 267625  https://dummyimage.com/641x790       ACTIVE
# 267626  https://dummyimage.com/641x790       ACTIVE
# 267627  https://dummyimage.com/641x790       ACTIVE
# 267628  https://dummyimage.com/641x790       ACTIVE
# 267629  https://dummyimage.com/641x790       ACTIVE
#
# [267630 rows x 45 columns]

# %%
final_df.columns
# Out:
# Index(['transactionId', 'invoiceId', 'customerId', 'userId', 'storeId',
#        'paymentMethodId', 'totalAmount', 'cash', 'change', 'discountPerson',
#        'transactionDate', 'statusTransaction', 'transactionDetailId',
#        'productId', 'variantId', 'quantity', 'subtotal', 'productCode',
#        'serialNumber', 'categoryId', 'productName', 'descriptionProduct',
#        'productDiscount', 'basePrice', 'imageUrl', 'isActive', 'createdAt',
#        'updatedAt', 'StoreCode', 'tenantId', 'storeName', 'image', 'address',
#        'provinceId', 'cityId', 'districtId', 'villageId', 'storeTypeId',
#        'postalCode', 'storeDescription', 'phoneNumber', 'logo', 'npwpCompany',
#        'permitCertificate', 'storeStatus'],
#       dtype='object')

# %%
#mengambil data toko dengan tipe toko id 1 yaitu fnb
final_df = final_df[final_df['storeTypeId'] == 10]
final_df
# Out:
#         transactionId         invoiceId  customerId  userId  storeId  \
# 111773          37309  INV-141196780560      2205.0     144       16
# 111774          37309  INV-141196780560      2205.0     144       16
# 111775          37309  INV-141196780560      2205.0     144       16
# 111776          37310  INV-339072024356      4576.0      94       16
# 111777          37311  INV-400477904222         NaN     139       16
# ...               ...               ...         ...     ...      ...
# 167025          55732  INV-662502382633      4149.0      94       16
# 167026          55733  INV-134151334611         NaN     144       16
# 167027          55733  INV-134151334611         NaN     144       16
# 167028          55733  INV-134151334611         NaN     144       16
# 167029          55733  INV-134151334611         NaN     144       16
#
#         paymentMethodId  totalAmount       cash  change  discountPerson  ...  \
# 111773                5    486433.92  489176.92  2743.0               0  ...
# 111774                5    486433.92  489176.92  2743.0               0  ...
# 111775                5    486433.92  489176.92  2743.0               0  ...
# 111776                1     33919.20   35460.20  1541.0               0  ...
# 111777                4    376984.16  379163.16  2179.0               0  ...
# ...                 ...          ...        ...     ...             ...  ...
# 167025                7    497021.28  499501.28  2480.0               0  ...
# 167026                1    724009.44  728752.44  4743.0               0  ...
# 167027                1    724009.44  728752.44  4743.0               0  ...
# 167028                1    724009.44  728752.44  4743.0               0  ...
# 167029                1    724009.44  728752.44  4743.0               0  ...
#
#        districtId villageId  storeTypeId  postalCode  \
# 111773       5783     61365           10       35944
# 111774       5783     61365           10       35944
# 111775       5783     61365           10       35944
# 111776       5783     61365           10       35944
# 111777       5783     61365           10       35944
# ...           ...       ...          ...         ...
# 167025       5783     61365           10       35944
# 167026       5783     61365           10       35944
# 167027       5783     61365           10       35944
# 167028       5783     61365           10       35944
# 167029       5783     61365           10       35944
#
#                                          storeDescription   phoneNumber  \
# 111773  Maiores cumque alias nam voluptatem. Ratione m...  628881612482
# 111774  Maiores cumque alias nam voluptatem. Ratione m...  628881612482
# 111775  Maiores cumque alias nam voluptatem. Ratione m...  628881612482
# 111776  Maiores cumque alias nam voluptatem. Ratione m...  628881612482
# 111777  Maiores cumque alias nam voluptatem. Ratione m...  628881612482
# ...                                                   ...           ...
# 167025  Maiores cumque alias nam voluptatem. Ratione m...  628881612482
# 167026  Maiores cumque alias nam voluptatem. Ratione m...  628881612482
# 167027  Maiores cumque alias nam voluptatem. Ratione m...  628881612482
# 167028  Maiores cumque alias nam voluptatem. Ratione m...  628881612482
# 167029  Maiores cumque alias nam voluptatem. Ratione m...  628881612482
#
#                                  logo                     npwpCompany  \
# 111773  https://picsum.photos/490/151  https://dummyimage.com/531x175
# 111774  https://picsum.photos/490/151  https://dummyimage.com/531x175
# 111775  https://picsum.photos/490/151  https://dummyimage.com/531x175
# 111776  https://picsum.photos/490/151  https://dummyimage.com/531x175
# 111777  https://picsum.photos/490/151  https://dummyimage.com/531x175
# ...                               ...                             ...
# 167025  https://picsum.photos/490/151  https://dummyimage.com/531x175
# 167026  https://picsum.photos/490/151  https://dummyimage.com/531x175
# 167027  https://picsum.photos/490/151  https://dummyimage.com/531x175
# 167028  https://picsum.photos/490/151  https://dummyimage.com/531x175
# 167029  https://picsum.photos/490/151  https://dummyimage.com/531x175
#
#                       permitCertificate  storeStatus
# 111773  https://placekitten.com/750/385       ACTIVE
# 111774  https://placekitten.com/750/385       ACTIVE
# 111775  https://placekitten.com/750/385       ACTIVE
# 111776  https://placekitten.com/750/385       ACTIVE
# 111777  https://placekitten.com/750/385       ACTIVE
# ...                                 ...          ...
# 167025  https://placekitten.com/750/385       ACTIVE
# 167026  https://placekitten.com/750/385       ACTIVE
# 167027  https://placekitten.com/750/385       ACTIVE
# 167028  https://placekitten.com/750/385       ACTIVE
# 167029  https://placekitten.com/750/385       ACTIVE
#
# [55257 rows x 45 columns]

# %%
final_df.columns
# Out:
# Index(['transactionId', 'invoiceId', 'customerId', 'userId', 'storeId',
#        'paymentMethodId', 'totalAmount', 'cash', 'change', 'discountPerson',
#        'transactionDate', 'statusTransaction', 'transactionDetailId',
#        'productId', 'variantId', 'quantity', 'subtotal', 'productCode',
#        'serialNumber', 'categoryId', 'productName', 'descriptionProduct',
#        'productDiscount', 'basePrice', 'imageUrl', 'isActive', 'createdAt',
#        'updatedAt', 'StoreCode', 'tenantId', 'storeName', 'image', 'address',
#        'provinceId', 'cityId', 'districtId', 'villageId', 'storeTypeId',
#        'postalCode', 'storeDescription', 'phoneNumber', 'logo', 'npwpCompany',
#        'permitCertificate', 'storeStatus'],
#       dtype='object')

# %%
selected_columns = [
    'transactionId', 'transactionDate', 'quantity', 'productId', 'storeId', 'categoryId',
# std          3.508332  3.634498e+05

# %% [markdown]
# ## Feature Engineering
#
# Tahapan ini digunakan untuk menambahkan, mengubah, atau menggabungkan fitur agar model bisa belajar lebih baik.
#
# - Fitur berbasis waktu
# - Fitur berbasis harga
# - Fitur berbasis produk
# - Fitur berbasis toko
# - Fitur agregasi historis

# %%
final_df['hour'] = final_df['transactionDate'].dt.hour
final_df['dayOfWeek'] = final_df['transactionDate'].dt.day_name()
final_df['month'] = final_df['transactionDate'].dt.month
final_df['isWeekend'] = final_df['transactionDate'].dt.dayofweek >= 5

final_df
# Out:
# <ipython-input-95-9aa93b287f66>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['hour'] = final_df['transactionDate'].dt.hour
# <ipython-input-95-9aa93b287f66>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['dayOfWeek'] = final_df['transactionDate'].dt.day_name()
# <ipython-input-95-9aa93b287f66>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['month'] = final_df['transactionDate'].dt.month
# <ipython-input-95-9aa93b287f66>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['isWeekend'] = final_df['transactionDate'].dt.dayofweek >= 5
#         transactionId     transactionDate  quantity  productId  storeId  \
# 111773          37309 2024-01-07 12:42:43         3        160       16
# 111774          37309 2024-01-07 12:42:43         2        154       16
# 111775          37309 2024-01-07 12:42:43         3        159       16
# 111776          37310 2024-01-07 16:27:50         1        153       16
# 111777          37311 2024-01-03 09:00:12         1        161       16
# ...               ...                 ...       ...        ...      ...
# 167025          55732 2024-01-25 10:33:40         3        152       16
# 167026          55733 2024-01-25 15:08:15         3        159       16
# 167027          55733 2024-01-25 15:08:15         5        157       16
# 167028          55733 2024-01-25 15:08:15         4        160       16
# 167029          55733 2024-01-25 15:08:15         1        151       16
#
#         categoryId  basePrice  productDiscount  discountPerson  totalAmount  \
# 111773          70      14000                0               0    486433.92
# 111774          74      78000                6               0    486433.92
# 111775          70      24000                0               0    486433.92
# 111776          70      15000                0               0     33919.20
# 111777          74      60000                0               0    376984.16
# ...            ...        ...              ...             ...          ...
# 167025          67      57000                0               0    497021.28
# 167026          70      24000                0               0    724009.44
# 167027          73      21000                0               0    724009.44
# 167028          70      14000                0               0    724009.44
# 167029          67      68000                0               0    724009.44
#
#         hour  dayOfWeek  month  isWeekend
# 111773    12     Sunday      1       True
# 111774    12     Sunday      1       True
# 111775    12     Sunday      1       True
# 111776    16     Sunday      1       True
# 111777     9  Wednesday      1      False
# ...      ...        ...    ...        ...
# 167025    10   Thursday      1      False
# 167026    15   Thursday      1      False
# 167027    15   Thursday      1      False
# 167028    15   Thursday      1      False
# 167029    15   Thursday      1      False
#
# [55257 rows x 14 columns]

# %%
final_df['dayOfWeek'].value_counts()
# Out:
# dayOfWeek
# Sunday       10612
# Saturday     10327
# Friday        8429
# Monday        6715
# Wednesday     6516
# Thursday      6389
# Tuesday       6269
# Name: count, dtype: int64

# %%
tax_rate = 0.11
final_df['effectivePrice'] = final_df['basePrice'] * (1 - final_df['productDiscount'] / 100)
final_df['effectivePriceWithTax'] = final_df['effectivePrice'] * (1 + tax_rate)
final_df['finalPricePerUnit'] = final_df['effectivePriceWithTax'] - (final_df['discountPerson'] / final_df['quantity'])
# Out:
# <ipython-input-97-34b35fcb6528>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['effectivePrice'] = final_df['basePrice'] * (1 - final_df['productDiscount'] / 100)
# <ipython-input-97-34b35fcb6528>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['effectivePriceWithTax'] = final_df['effectivePrice'] * (1 + tax_rate)
# <ipython-input-97-34b35fcb6528>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['finalPricePerUnit'] = final_df['effectivePriceWithTax'] - (final_df['discountPerson'] / final_df['quantity'])

# %%
# final_df['total_quantity_product'] = final_df.groupby('productId')['quantity'].transform('sum')
# final_df['avg_sales_product'] = final_df.groupby('productId')['totalAmount'].transform('mean')

# # final_df

# %%
final_df['transactionSize'] = final_df.groupby('transactionId')['quantity'].transform('sum')
final_df['avgTransactionValue'] = final_df.groupby('storeId')['totalAmount'].transform('mean')
# Out:
# <ipython-input-99-6bed933002f0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['transactionSize'] = final_df.groupby('transactionId')['quantity'].transform('sum')
# <ipython-input-99-6bed933002f0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['avgTransactionValue'] = final_df.groupby('storeId')['totalAmount'].transform('mean')

# %%
final_df['rollingAvg7d'] = final_df.groupby('productId')['totalAmount'].rolling(window=7).mean().reset_index(level=0, drop=True)
final_df
# Out:
# <ipython-input-100-08e6f3e6e494>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['rollingAvg7d'] = final_df.groupby('productId')['totalAmount'].rolling(window=7).mean().reset_index(level=0, drop=True)
#         transactionId     transactionDate  quantity  productId  storeId  \
# 111773          37309 2024-01-07 12:42:43         3        160       16
# 111774          37309 2024-01-07 12:42:43         2        154       16
# 111775          37309 2024-01-07 12:42:43         3        159       16
# 111776          37310 2024-01-07 16:27:50         1        153       16
# 111777          37311 2024-01-03 09:00:12         1        161       16
# ...               ...                 ...       ...        ...      ...
# 167025          55732 2024-01-25 10:33:40         3        152       16
# 167026          55733 2024-01-25 15:08:15         3        159       16
# 167027          55733 2024-01-25 15:08:15         5        157       16
# 167028          55733 2024-01-25 15:08:15         4        160       16
# 167029          55733 2024-01-25 15:08:15         1        151       16
#
#         categoryId  basePrice  productDiscount  discountPerson  totalAmount  \
# 111773          70      14000                0               0    486433.92
# 111774          74      78000                6               0    486433.92
# 111775          70      24000                0               0    486433.92
# 111776          70      15000                0               0     33919.20
# 111777          74      60000                0               0    376984.16
# ...            ...        ...              ...             ...          ...
# 167025          67      57000                0               0    497021.28
# 167026          70      24000                0               0    724009.44
# 167027          73      21000                0               0    724009.44
# 167028          70      14000                0               0    724009.44
# 167029          67      68000                0               0    724009.44
#
#         hour  dayOfWeek  month  isWeekend  effectivePrice  \
# 111773    12     Sunday      1       True         14000.0
# 111774    12     Sunday      1       True         73320.0
# 111775    12     Sunday      1       True         24000.0
# 111776    16     Sunday      1       True         15000.0
# 111777     9  Wednesday      1      False         60000.0
# ...      ...        ...    ...        ...             ...
# 167025    10   Thursday      1      False         57000.0
# 167026    15   Thursday      1      False         24000.0
# 167027    15   Thursday      1      False         21000.0
# 167028    15   Thursday      1      False         14000.0
# 167029    15   Thursday      1      False         68000.0
#
#         effectivePriceWithTax  finalPricePerUnit  transactionSize  \
# 111773                15540.0            15540.0                8
# 111774                81385.2            81385.2                8
# 111775                26640.0            26640.0                8
# 111776                16650.0            16650.0                1
# 111777                66600.0            66600.0                5
# ...                       ...                ...              ...
# 167025                63270.0            63270.0                9
# 167026                26640.0            26640.0               13
# 167027                23310.0            23310.0               13
# 167028                15540.0            15540.0               13
# 167029                75480.0            75480.0               13
#
#         avgTransactionValue   rollingAvg7d
# 111773        753530.313203            NaN
# 111774        753530.313203            NaN
# 111775        753530.313203            NaN
# 111776        753530.313203            NaN
# 111777        753530.313203            NaN
# ...                     ...            ...
# 167025        753530.313203  707077.960000
# 167026        753530.313203  746444.914286
# 167027        753530.313203  563757.280000
# 167028        753530.313203  780221.022857
# 167029        753530.313203  660514.782857
#
# [55257 rows x 20 columns]

# %%
le = LabelEncoder()
final_df['dayOfWeek'] = le.fit_transform(final_df['dayOfWeek'])
final_df
# Out:
# <ipython-input-101-bb47f653789e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['dayOfWeek'] = le.fit_transform(final_df['dayOfWeek'])
#         transactionId     transactionDate  quantity  productId  storeId  \
# 111773          37309 2024-01-07 12:42:43         3        160       16
# 111774          37309 2024-01-07 12:42:43         2        154       16
# 111775          37309 2024-01-07 12:42:43         3        159       16
# 111776          37310 2024-01-07 16:27:50         1        153       16
# 111777          37311 2024-01-03 09:00:12         1        161       16
# ...               ...                 ...       ...        ...      ...
# 167025          55732 2024-01-25 10:33:40         3        152       16
# 167026          55733 2024-01-25 15:08:15         3        159       16
# 167027          55733 2024-01-25 15:08:15         5        157       16
# 167028          55733 2024-01-25 15:08:15         4        160       16
# 167029          55733 2024-01-25 15:08:15         1        151       16
#
#         categoryId  basePrice  productDiscount  discountPerson  totalAmount  \
# 111773          70      14000                0               0    486433.92
# 111774          74      78000                6               0    486433.92
# 111775          70      24000                0               0    486433.92
# 111776          70      15000                0               0     33919.20
# 111777          74      60000                0               0    376984.16
# ...            ...        ...              ...             ...          ...
# 167025          67      57000                0               0    497021.28
# 167026          70      24000                0               0    724009.44
# 167027          73      21000                0               0    724009.44
# 167028          70      14000                0               0    724009.44
# 167029          67      68000                0               0    724009.44
#
#         hour  dayOfWeek  month  isWeekend  effectivePrice  \
# 111773    12          3      1       True         14000.0
# 111774    12          3      1       True         73320.0
# 111775    12          3      1       True         24000.0
# 111776    16          3      1       True         15000.0
# 111777     9          6      1      False         60000.0
# ...      ...        ...    ...        ...             ...
# 167025    10          4      1      False         57000.0
# 167026    15          4      1      False         24000.0
# 167027    15          4      1      False         21000.0
# 167028    15          4      1      False         14000.0
# 167029    15          4      1      False         68000.0
#
#         effectivePriceWithTax  finalPricePerUnit  transactionSize  \
# 111773                15540.0            15540.0                8
# 111774                81385.2            81385.2                8
# 111775                26640.0            26640.0                8
# 111776                16650.0            16650.0                1
# 111777                66600.0            66600.0                5
# ...                       ...                ...              ...
# 167025                63270.0            63270.0                9
# 167026                26640.0            26640.0               13
# 167027                23310.0            23310.0               13
# 167028                15540.0            15540.0               13
# 167029                75480.0            75480.0               13
#
#         avgTransactionValue   rollingAvg7d
# 111773        753530.313203            NaN
# 111774        753530.313203            NaN
# 111775        753530.313203            NaN
# 111776        753530.313203            NaN
# 111777        753530.313203            NaN
# ...                     ...            ...
# 167025        753530.313203  707077.960000
# 167026        753530.313203  746444.914286
# 167027        753530.313203  563757.280000
# 167028        753530.313203  780221.022857
# 167029        753530.313203  660514.782857
#
# [55257 rows x 20 columns]

# %%
final_backup_df = final_df.copy()
final_df.drop(['transactionDate', 'dayOfWeek'], axis=1)
# Out:
#         transactionId  quantity  productId  storeId  categoryId  basePrice  \
# 111773          37309         3        160       16          70      14000
# 111774          37309         2        154       16          74      78000
# 111775          37309         3        159       16          70      24000
# 111776          37310         1        153       16          70      15000
# 111777          37311         1        161       16          74      60000
# ...               ...       ...        ...      ...         ...        ...
# 167025          55732         3        152       16          67      57000
# 167026          55733         3        159       16          70      24000
# 167027          55733         5        157       16          73      21000
# 167028          55733         4        160       16          70      14000
# 167029          55733         1        151       16          67      68000
#
#         productDiscount  discountPerson  totalAmount  hour  month  isWeekend  \
# 111773                0               0    486433.92    12      1       True
# 111774                6               0    486433.92    12      1       True
# 111775                0               0    486433.92    12      1       True
# 111776                0               0     33919.20    16      1       True
# 111777                0               0    376984.16     9      1      False
# ...                 ...             ...          ...   ...    ...        ...
# 167025                0               0    497021.28    10      1      False
# 167026                0               0    724009.44    15      1      False
# 167027                0               0    724009.44    15      1      False
# 167028                0               0    724009.44    15      1      False
# 167029                0               0    724009.44    15      1      False
#
#         effectivePrice  effectivePriceWithTax  finalPricePerUnit  \
# 111773         14000.0                15540.0            15540.0
# 111774         73320.0                81385.2            81385.2
# 111775         24000.0                26640.0            26640.0
# 111776         15000.0                16650.0            16650.0
# 111777         60000.0                66600.0            66600.0
# ...                ...                    ...                ...
# 167025         57000.0                63270.0            63270.0
# 167026         24000.0                26640.0            26640.0
# 167027         21000.0                23310.0            23310.0
# 167028         14000.0                15540.0            15540.0
# 167029         68000.0                75480.0            75480.0
#
#         transactionSize  avgTransactionValue   rollingAvg7d
# 111773                8        753530.313203            NaN
# 111774                8        753530.313203            NaN
# 111775                8        753530.313203            NaN
# 111776                1        753530.313203            NaN
# 111777                5        753530.313203            NaN
# ...                 ...                  ...            ...
# 167025                9        753530.313203  707077.960000
# 167026               13        753530.313203  746444.914286
# 167027               13        753530.313203  563757.280000
# 167028               13        753530.313203  780221.022857
# 167029               13        753530.313203  660514.782857
#
# [55257 rows x 18 columns]

# %%
final_df.hist(bins=50, figsize=(16, 12))
plt.show()

# %%
corr_matrix = final_df.corr()

plt.figure(figsize=(16, 12))

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')

plt.title('Korelasi Antar Variabel')

plt.show()

# %% [markdown]
# ## Data Pre-processing

# %%
copy_df = final_df.copy()
copy_df = copy_df.dropna()
copy_df_with_date = copy_df.copy()

# %%
copy_df_with_date['transactionDate'] = final_df['transactionDate']
copy_df_with_date = copy_df_with_date.sort_values('transactionDate')
last_date = copy_df_with_date['transactionDate'].max()
cutoff_date = last_date - pd.Timedelta(days=30)

# %%
train_df = copy_df_with_date[copy_df_with_date['transactionDate'] < cutoff_date]
test_df = copy_df_with_date[copy_df_with_date['transactionDate'] >= cutoff_date]

# %%
selected_columns = ['quantity', 'basePrice', 'productDiscount', 'hour', 'isWeekend',
                    'effectivePrice', 'effectivePriceWithTax', 'finalPricePerUnit',
                    'rollingAvg7d', 'transactionSize']

X_train = train_df[selected_columns]
y_train = train_df['totalAmount']
X_test = test_df[selected_columns]
y_test = test_df['totalAmount']

# %%
scaler = StandardScaler()
features = ['quantity', 'basePrice', 'productDiscount', 'hour',
            'effectivePrice', 'effectivePriceWithTax', 'finalPricePerUnit',
            'rollingAvg7d', 'transactionSize']

scaler.fit(X_train[features])
X_train[features] = scaler.transform(X_train[features])
X_test[features] = scaler.transform(X_test[features])
# Out:
# <ipython-input-111-ab20d46d4e1b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[features] = scaler.transform(X_train[features])
# <ipython-input-111-ab20d46d4e1b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[features] = scaler.transform(X_test[features])

# %% [markdown]
# ## Modeling

# %%
import matplotlib.dates as mdates

models = {
    'LinearRegression': LinearRegression(),
    'DecisionTree': DecisionTreeRegressor(),
    'RandomForest': RandomForestRegressor(),
    'KNearestNeighbor': KNeighborsRegressor(),
    'NeuralNetwork': MLPRegressor(),
    'ADABoost': AdaBoostRegressor(),
    'GradientBoosting': GradientBoostingRegressor()
}

result = {}

# Setelah melatih model dan mendapatkan prediksi
for name, model in models.items():
    # Latih model
    model.fit(X_train, y_train)
    # Prediksi pada test set
    y_pred = model.predict(X_test)

    # Simpan metrik evaluasi
    result[name] = {
        'MAE': mean_absolute_error(y_test, y_pred),
        'MSE': mean_squared_error(y_test, y_pred),
        'R2-Score': r2_score(y_test, y_pred)
    }

    # Agregasi total penjualan aktual per hari
    actual_daily = test_df.groupby('transactionDate')['totalAmount'].sum().reset_index()
    actual_daily.columns = ['Tanggal', 'Total Penjualan Aktual']

    # Agregasi total penjualan prediksi per hari
    temp_df = test_df[['transactionDate']].copy()
    temp_df['pred_amount'] = y_pred
    predicted_daily = temp_df.groupby('transactionDate')['pred_amount'].sum().reset_index()
    predicted_daily.columns = ['Tanggal', 'Total Penjualan Prediksi']


    # Gabungkan data aktual dan prediksi
    daily_comparison = pd.merge(actual_daily, predicted_daily, on='Tanggal', how='left')

    daily_comparison = daily_comparison.sort_values('Tanggal')
    daily_comparison = daily_comparison.tail(28)

    # Visualisasi perbandingan aktual vs prediksi per hari
    plt.figure(figsize=(12, 6))
    plt.plot(daily_comparison['Tanggal'], daily_comparison['Total Penjualan Aktual'],
             marker='o', markersize=8, linestyle='-', linewidth=2, color='blue', label='Aktual')
    plt.plot(daily_comparison['Tanggal'], daily_comparison['Total Penjualan Prediksi'],
             marker='x', markersize=8, linestyle='--', linewidth=2, color='orange', label='Prediksi')

    # Judul dan label
    plt.title(f'Perbandingan Total Penjualan Aktual vs Prediksi Per Hari - {name}', fontsize=14)
    plt.xlabel('Tanggal', fontsize=12)
    plt.ylabel('Total Penjualan (Rp)', fontsize=12)

    # Format sumbu x untuk tanggal
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=1))  # Tampilkan setiap hari
    plt.xticks(rotation=45)

    # Tambahkan grid dan legenda
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend()

    # Sesuaikan layout
    plt.tight_layout()
    plt.show()

# Tampilkan hasil evaluasi
print("\nHasil Evaluasi Model:")
print(pd.DataFrame(result))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Hasil Evaluasi Model:
#           LinearRegression  DecisionTree  RandomForest  KNearestNeighbor  \
# MAE           1.317084e+05  1.879693e+05  1.373484e+05      1.416748e+05
# MSE           2.928784e+10  5.922180e+10  3.189678e+10      3.465374e+10
# R2-Score      7.800229e-01  5.551929e-01  7.604275e-01      7.397203e-01
#
#           NeuralNetwork      ADABoost  GradientBoosting
# MAE        2.595075e+05  1.427104e+05      1.284906e+05
# MSE        1.069261e+11  3.262329e+10      2.827976e+10
# R2-Score   1.968924e-01  7.549708e-01      7.875944e-01

# %%
pd.DataFrame(result)
# Out:
#           LinearRegression  DecisionTree  RandomForest  KNearestNeighbor  \
# MAE           1.317084e+05  1.879693e+05  1.373484e+05      1.416748e+05
# MSE           2.928784e+10  5.922180e+10  3.189678e+10      3.465374e+10
# R2-Score      7.800229e-01  5.551929e-01  7.604275e-01      7.397203e-01
#
#           NeuralNetwork      ADABoost  GradientBoosting
# MAE        2.595075e+05  1.427104e+05      1.284906e+05
# MSE        1.069261e+11  3.262329e+10      2.827976e+10
# R2-Score   1.968924e-01  7.549708e-01      7.875944e-01

# %%
gbr = GradientBoostingRegressor()

param_grid = {
    'n_estimators': [32, 64, 100, 150, 200],
    'learning_rate': [1.0, 0.5, 0.3, 0.25, 0.2, 0.1, 0.05, 0.01, 0.005],
    'max_depth': [3, 4, 5, 6, 7, 8, 10],
    'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
    'min_samples_split': [2, 3, 4, 5, 6, 8, 10]
}

grid_search = GridSearchCV(estimator=gbr, param_grid=param_grid,
                           scoring='neg_mean_squared_error', cv=5, n_jobs=-1, verbose=1)

grid_search.fit(X_train, y_train)

print("Best Parameters:", grid_search.best_params_)
best_gb = grid_search.best_estimator_

y_pred = best_gb.predict(X_test)
print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("R2-Score:", r2_score(y_test, y_pred))
# Out:
# Fitting 5 folds for each of 13230 candidates, totalling 66150 fits

# %%
ab_param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.5, 1.0],
    'loss': ['linear', 'square', 'exponential'],
    'estimator': [DecisionTreeRegressor(max_depth=1), DecisionTreeRegressor(max_depth=2)]
}

# Initialize AdaBoost
adaboost = AdaBoostRegressor(random_state=42)

# Perform Grid Search
grid_search = GridSearchCV(adaboost, ab_param_grid, cv=5, scoring='neg_mean_absolute_error', n_jobs=-1)
grid_search.fit(X_train, y_train)

# Best parameters and model
print("Best Parameters:", grid_search.best_params_)
best_adaboost = grid_search.best_estimator_

# Evaluate
y_pred = best_adaboost.predict(X_test)
print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("R2-Score:", r2_score(y_test, y_pred))
# Out:
# Best Parameters: {'estimator': DecisionTreeRegressor(max_depth=2), 'learning_rate': 0.01, 'loss': 'linear', 'n_estimators': 200}
# MAE: 425397.7815951469
# MSE: 299918842743.8617
# R2-Score: 0.284918002738625

# %%
# Agregasi total penjualan aktual per hari
actual_daily = test_df.groupby('transactionDate')['totalAmount'].sum().reset_index()
actual_daily.columns = ['Tanggal', 'Total Penjualan Aktual']

# Agregasi total penjualan prediksi per hari
temp_df = test_df[['transactionDate']].copy()
temp_df['pred_tuning_amount'] = y_pred
predicted_daily = temp_df.groupby('transactionDate')['pred_tuning_amount'].sum().reset_index()
predicted_daily.columns = ['Tanggal', 'Total Penjualan Prediksi']

# Gabungkan data aktual dan prediksi
daily_comparison = pd.merge(actual_daily, predicted_daily, on='Tanggal', how='left')

# Batasi data untuk 14 hari terakhir agar pola lebih jelas
daily_comparison = daily_comparison.sort_values('Tanggal')
daily_comparison = daily_comparison.tail(14)  # Ambil 14 hari terakhir

# Visualisasi perbandingan aktual vs prediksi per hari
plt.figure(figsize=(12, 6))
plt.plot(daily_comparison['Tanggal'], daily_comparison['Total Penjualan Aktual'],
          marker='o', markersize=8, linestyle='-', linewidth=2, color='blue', label='Aktual')
plt.plot(daily_comparison['Tanggal'], daily_comparison['Total Penjualan Prediksi'],
          marker='x', markersize=8, linestyle='--', linewidth=2, color='orange', label='Prediksi')

# Judul dan label
plt.title(f'Perbandingan Total Penjualan Aktual vs Prediksi Per Hari - {name}', fontsize=14)
plt.xlabel('Tanggal', fontsize=12)
plt.ylabel('Total Penjualan (Rp)', fontsize=12)

# Format sumbu x untuk tanggal
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=1))  # Tampilkan setiap hari
plt.xticks(rotation=45)

# Tambahkan grid dan legenda
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Sesuaikan layout
plt.tight_layout()
plt.show()

# %%
rf_param_grid = {
    'n_estimators': [50, 100, 200, 300],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

rf_model = RandomForestRegressor()

rf_grid_search = GridSearchCV(estimator=rf_model, param_grid=rf_param_grid,
                              cv=5, scoring='neg_mean_squared_error', n_jobs=-1,
                              verbose=1)

rf_grid_search.fit(X_train, y_train)

print("RandomForest - Parameter Terbaik:", rf_grid_search.best_params_)
print("RandomForest - Skor Terbaik (neg MSE):", rf_grid_search.best_score_)

# Evaluasi model terbaik pada test set
rf_best = rf_grid_search.best_estimator_
y_pred_rf = rf_best.predict(X_test)
print("RandomForest - MAE:", mean_absolute_error(y_test, y_pred_rf))
print("RandomForest - MSE:", mean_squared_error(y_test, y_pred_rf))
print("RandomForest - R2-Score:", r2_score(y_test, y_pred_rf))
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# /usr/local/lib/python3.11/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# RandomForest - Parameter Terbaik: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# RandomForest - Skor Terbaik (neg MSE): -276080349030.2529
# RandomForest - MAE: 407861.4962777243
# RandomForest - MSE: 276800182584.3302
# RandomForest - R2-Score: 0.34003870649181744

# %%
# Agregasi total penjualan aktual per hari
actual_daily = test_df.groupby('transactionDate')['totalAmount'].sum().reset_index()
actual_daily.columns = ['Tanggal', 'Total Penjualan Aktual']

# Agregasi total penjualan prediksi per hari
temp_df = test_df[['transactionDate']].copy()
temp_df['pred_tuning_amount'] = y_pred_rf
predicted_daily = temp_df.groupby('transactionDate')['pred_tuning_amount'].sum().reset_index()
predicted_daily.columns = ['Tanggal', 'Total Penjualan Prediksi']

# Gabungkan data aktual dan prediksi
daily_comparison = pd.merge(actual_daily, predicted_daily, on='Tanggal', how='left')

# Batasi data untuk 14 hari terakhir agar pola lebih jelas
daily_comparison = daily_comparison.sort_values('Tanggal')
daily_comparison = daily_comparison.tail(14)  # Ambil 14 hari terakhir

# Visualisasi perbandingan aktual vs prediksi per hari
plt.figure(figsize=(12, 6))
plt.plot(daily_comparison['Tanggal'], daily_comparison['Total Penjualan Aktual'],
          marker='o', markersize=8, linestyle='-', linewidth=2, color='blue', label='Aktual')
plt.plot(daily_comparison['Tanggal'], daily_comparison['Total Penjualan Prediksi'],
          marker='x', markersize=8, linestyle='--', linewidth=2, color='orange', label='Prediksi')

# Judul dan label
plt.title(f'Perbandingan Total Penjualan Aktual vs Prediksi Per Hari - {name}', fontsize=14)
plt.xlabel('Tanggal', fontsize=12)
plt.ylabel('Total Penjualan (Rp)', fontsize=12)

# Format sumbu x untuk tanggal
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=1))  # Tampilkan setiap hari
plt.xticks(rotation=45)

# Tambahkan grid dan legenda
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Sesuaikan layout
plt.tight_layout()
plt.show()
